# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# %%bash
# pip install scikit-learn

# %%
trainData = pd.read_csv('./data/amazon_review_full_csv/train.csv', header=None, names=['rating', 'title', 'review'])

# %%
# from sklearn.model_selection import train_test_split
# trainData = train_test_split(data, test_size = 0.1, random_state = 1)

# %%
# count = (trainData.rating == 1).count()
# count

# %%
# count = (trainData.rating == 2).count()
# count
# trainData[trainData.rating == 1].count()
# trainData[trainData.rating == 5].count()

# %%
# trainData.head(10)

# %%
# x = trainData.head(10)[['title', 'review']].get_values()
x = trainData.head(500000).review.get_values()
# y = trainData.head(10).rating.get_values()
# x
# y

# %%
y = trainData.head(500000).rating.get_values()
# y

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = 1)

# %%
# x_train

# %%
# x_test

# %%
y_train
# Out:
# array([3, 1, 3, ..., 5, 4, 2])

# %%
# y_test

# %%
# reviews = trainData.head(10).review.get_values()

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# count_vect = CountVectorizer()
# train_counts = count_vect.fit_transform(reviews).toarray()
# train_counts
# train_counts.shape

# %%
# from sklearn.naive_bayes import MultinomialNB
# clf = MultinomialNB().fit(x_train, y_train)
# pred = clf.predict(x_train)
# np.mean(pred == y_train)

# %%
# x_train

# %%
y_train_array = []
for item in y_train:
    y_train_array.append([item])
y_train_array
# Out:
# [[3],
#  [1],
#  [3],
#  [1],
#  [3],
#  [2],
#  [2],
#  [5],
#  [5],
#  [4],
#  [1],
#  [4],
#  [5],
#  [2],
#  [1],
#  [2],
#  [2],
#  [4],
#  [2],
#  [3],
#  [5],
#  [2],
#  [2],
#  [1],
#  [4],
#  [3],
#  [2],
#  [5],
#  [5],
#  [4],
#  [3],
#  [3],
#  [2],
#  [2],
#  [2],
#  [4],
#  [1],
#  [4],
#  [2],
#  [4],
#  [1],
#  [1],
#  [5],
#  [1],
#  [1],
#  [5],
#  [4],
#  [3],
#  [4],
#  [4],
#  [5],
#  [2],
#  [4],
#  [4],
#  [3],
#  [3],
#  [4],
#  [3],
#  [3],
#  [2],
#  [2],
#  [3],
#  [5],
#  [1],
#  [3],
#  [5],
#  [3],
#  [1],
#  [4],
#  [4],
#  [4],
#  [4],
#  [2],
#  [1],
#  [1],
#  [1],
#  [2],
#  [2],
#  [2],
#  [2],
#  [3],
#  [2],
#  [1],
#  [2],
#  [4],
#  [3],
#  [1],
#  [5],
#  [4],
#  [3],
#  [2],
#  [3],
#  [5],
#  [4],
#  [5],
#  [3],
#  [2],
#  [3],
#  [3],
#  [4],
#  [4],
#  [5],
#  [4],
#  [5],
#  [4],
#  [4],
#  [2],
#  [2],
#  [3],
#  [4],
#  [2],
#  [4],
#  [1],
#  [1],
#  [1],
#  [3],
#  [1],
#  [3],
#  [4],
#  [3],
#  [5],
#  [4],
#  [4],
#  [4],
#  [3],
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
count_vect = CountVectorizer()

x_train_trans = count_vect.fit_transform(x_train)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
count_vect = CountVectorizer()

x_train_trans = count_vect.fit_transform(x_train)

# y_train_trans = []
# for item in y_train:
#     y_train_trans.append([item])
    
# y_train_trans = count_vect.fit(y_train)

# clf = MultinomialNB().fit(x_train_trans.data, y_train)


clf = MultinomialNB().fit(x_train_trans.data, y_train_array)

x_test_trans = [count_vect.fit_transform(x_test)]
# x_test_data = x_test_trans.data

predicted = clf.predict(x_test_trans.data)

# np.mean(predicted == y_test)


# x_train_new = []
# for item in x_train:
#     x_train_new.append(count_vect.fit_transform(item).toarray())
# x_train_new

# x_train_trans = MultinomialNB().fit(x_train)

# x_train_trans = count_vect.fit_transform(x_train)
# x_train_fit = count_vect.fit_transform(x_train).toarray()
# x_test_fit = count_vect.fit_transform(x_test).toarray()

# clf = MultinomialNB().fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-e08ba3993365> in <module>
#      14
#      15
# ---> 16 clf = MultinomialNB().fit(x_train_trans.data, y_train_array)
#      17
#      18 x_test_trans = [count_vect.fit_transform(x_test)]
#
# /anaconda3/envs/amazon-nlp-env/lib/python3.7/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     586         self : object
#     587         """
# --> 588         X, y = check_X_y(X, y, 'csr')
#     589         _, n_features = X.shape
#     590
#
# /anaconda3/envs/amazon-nlp-env/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...
